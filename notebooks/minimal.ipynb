# %% [markdown]
# This notebook showcases the functionality of `galCIB`.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import galCIB

import matplotlib.pyplot as plt

# %% [markdown]
# `galCIB` is a tool that calculates the expected galaxy x galaxy, galaxy x CIB and CIB x CIB power spectra (3D or 2D), given certain parameters.
#
# It is a highly flexible model that uses a halo-model approach to connect physical properties of interest such as the cosmic star formation history, halo dust temperature, galaxy halo properties, etc. with the observed power spectra.

# %% [markdown]
# Currently, the default mode calculates the projected 2D power spectra, $C(\ell)$, given these parameters. Mathematically, our model appears as follows:
#
# \begin{equation}
#     C_{\rm XY} (\ell) = \int_{z_{\rm min}}^{z_{\rm max}} \frac{dz}{c} \frac{H(z)}{\chi^2(z)} W_{\rm X} (z) W_{\rm Y} (z) P_{\rm XY} \left( k = \frac{\ell + 1/2}{\chi}, z \right)
# \end{equation}
#
# where, the left-hand side is our predicted cross-correlation between two fields, $X$ and $Y$; in our case {$X$,$Y$} $\in$ {galaxy, CIB}.

# %% [markdown]
# `galCIB` streamlines the process of calculating these integrals with flexible-user defined functions. Below we showcase each of the steps needed to build a pipeline of your choice. Each aspect of this integral is broken into classes that takes care of its own calculations.
#
# Below we showcase how to build up the analysis pipeline with `galCIB`.

# %% [markdown]
# # Step 0: Setup `Survey` parameters.
#
# A galaxy X CIB analysis requires one to specify both the galaxy and the CIB surveys. Here are the required ingredients.

# %% [markdown]
# ## Galaxy Survey
#
# The user specifies the redshift distribution of the galaxy sample. As an example, we use the DESI Photometric ELG sample from [Karim et al. 2025](https://arxiv.org/abs/2408.15909). The user also has to define the magnification bias of the galaxy sample. Note that we use the $\alpha$ parameter convention as opposed to the $s$ parameter convention in `galCIB`.

# %%
# Define redshift distribution
dndz_file=np.load("/Users/tanveerk/research/Macintosh HD/Users/tkarim/research/galCIB/data/gal/dndz_extended.p",
        allow_pickle=True)
zs=dndz_file['zrange']
pz=dndz_file['dndz'].mean(axis=0)

zs = np.concatenate((zs,np.arange(2.85, 10.05, 0.1)[2:]))
pz = np.concatenate((pz,np.arange(2.85, 10.05, 0.1)[2:]*0))

plt.plot(zs, pz)

# Define magnification bias
mag_alpha = 2.225

# %% [markdown]
# ## CIB Survey
#
# The user specifies the frequency channels to be observed and their associated filter curves. By default, we have the *Planck* $353$, $545$, and $857$ GHz channels implemented.

# %%
nu_obs = [353, 545, 857] # Planck effective freq. in GHz

# load Planck filter response curves 
from galCIB.utils.io import load_my_filters

cib_filters = load_my_filters("/Users/tanveerk/research/Macintosh HD/Users/tkarim/research/galCIB/data/filters/",
                nu_obs=nu_obs)

# %% [markdown]
# # Step 1: Setup `Survey`
#
# With the essential ingredients specified, we can now setup the `Survey` class. Note that as performing an angular clustering analysis, we also need to define the range of $\ell$ to be used in the analysis and the resolution of the CIB maps given by `NSIDE`.
#
# Given these information, we setup the object `example_survey`.

# %%
from galCIB import Survey 

LMIN = 100; LMAX=2000
ells = np.arange(LMIN, LMAX)
NSIDE = 1024 

example_survey = Survey(z=zs, 
                 pz=pz, mag_alpha=mag_alpha,  
                 cib_filters=cib_filters,
                 ells=ells, nside=NSIDE,
                 name="Example")

# %% [markdown]
# # Setup `Cosmology`
#
# Next, the user has to define what cosmology they want to perform their analysis in. `galCIB` assumes a specific cosmology to run. In the future, we may implement flexibilty to vary cosmology along with CIB parameters.
#
# `galCIB` is integrated with the [`colossus`](https://www.benediktdiemer.com/code/colossus/) package which takes care of halo-mass function-related calculations. Right now, you can specify one of the many [standard cosmologies](https://bdiemer.bitbucket.io/colossus/cosmology_cosmology.html) implemented in `colossus`. Simply pass the named string from the `ID` column to the argument `colossus_cosmo_name`. In the future we may implement user-specific cosmological parameters.
#
# We also allow the user to specify whether all the calculations should be done in $h^{-1}$ units with the boolean flag `use_little_h`.

# %%
ks = np.logspace(-3,1,500)
Mh = np.logspace(7,15,100)

from galCIB import Cosmology

cosmo = Cosmology(example_survey.z, ks, Mh,
                  colossus_cosmo_name='planck18',
                  use_little_h=False)

# %% [markdown]
# There are lots of important calculations that are cached in `cosmo` which the user can access if they wish to. For example, you can obtain the value of the Hubble constant by running `cosmo.H0` or take a look at your Halo-Mass Function by calling `cosmo.get_hmf_grid()`.

# %%
print(cosmo.H0)
print(cosmo.get_hmf_grid())
# Out:
# 67.66
# [[1.43009041e+002 1.43151793e+002 1.43523619e+002 ... 7.81893141e+001
#   7.62976205e+001 7.44253950e+001]
#  [1.20183898e+002 1.20323168e+002 1.20654969e+002 ... 6.34300320e+001
#   6.18439955e+001 6.02758188e+001]
#  [1.01011732e+002 1.01145191e+002 1.01440461e+002 ... 5.13816427e+001
#   5.00536932e+001 4.87420197e+001]
#  ...
#  [2.75332670e-006 2.06821215e-006 1.49986222e-006 ... 3.38052240e-091
#   8.14797289e-093 1.89742868e-094]
#  [1.84885765e-006 1.34449127e-006 9.40492157e-007 ... 8.37657524e-100
#   1.39864673e-101 2.24870944e-103]
#  [1.20079239e-006 8.42049096e-007 5.65698421e-007 ... 1.96246963e-109
#   2.17235938e-111 2.30675898e-113]]

# %% [markdown]
# ## Calculate Radial Kernels $W_X$
#
# To calculate the radial kernels $W_X$ in the Limber integration, one has to first specify a cosmology. Once both `Survey` and `Cosmology` are setup, **make sure to compute the window before moving forward**.
#
# Below we show how the kernels look like for the galaxy sample.

# %%
# Calculate window 

example_survey.compute_windows(cosmo)
plt.plot(cosmo.z, example_survey.Wg, label = r'$W_g$')
plt.plot(cosmo.z, example_survey.Wmu, label = r'$W_{\mu}$')
plt.xlabel("Redshift z")
plt.legend(loc='best')

# %% [markdown]
# # Step 4: Setup `HODModel` of the galaxy sample
#
# Now we are getting into the weeds of the modeling. `galCIB` takes a halo-occupation distribution approach to measure galaxy clustering. The user can define their own HOD functions for central and satellite galaxies and pass it to the class `HODModel`.
#
# Make sure that the output of your function is of the shape ($N_{M_h}$, $N_z$). Here $N_{M_h}$ is the number of halo mass bins and $N_z$ is the number of redshift bins.
#
# We have implemented two default HOD models, the original Zheng 2005 model as `Zheng-05` and the DESI ELG HOD model as `DESI-ELG`. If you want to use either of these, you can instantiate them by calling `get_hod_model`.

# %%
from galCIB import get_hod_model
elg_hod_model = get_hod_model("DESI-ELG", cosmo)

# %% [markdown]
# # Step 5: Setup `SatProfile`
#
# In the halo model approach, one has to also specify the radial profile of the satellite galaxies to properly calculate the $1$-halo term of the power spectra.
#
# By default, most analyses assume an NFW profile which `galCIB` supports. We also have a mixed profile that is a mixture of the NFW and an exponential decay profile, following the characteristics of the ELG satellites in [Rocher et al. 2024](https://arxiv.org/abs/2306.06319). In this example, we use the mixed model. The description of the exponential decay parameters can be found in the cited paper.

# %%
from galCIB import SatProfile

theta_prof = np.array([0.3, 6.14, 1]) # fexp, tau, LambdaNFW
elg_sat_profile = SatProfile(cosmo, theta_prof, profile_type='mixed')
# Out:
# /Users/tanveerk/research/Macintosh HD/Users/tkarim/research/galCIB/src/galCIB/satprofile/profile.py:39: UserWarning: For the default mixed profile, theta should be [f_exp, tau_exp, lambda_NFW].
#   warnings.warn(

# %% [markdown]
# On the other hand, CIB-emitters are often modeled as following the canonical NFW profile ([Yan et al. 2023](https://arxiv.org/pdf/2310.10848)). We can use two different profiles to describe the two different galaxy populations. Since NFW profile is fixed for a given cosmology, Halo Mass Function and concentration definition, we do not have to pass any parameters to initialize it.

# %%
cib_sat_profile = SatProfile(cosmo, None, profile_type='nfw')

# %% [markdown]
# # Step 6: Setup `SFRModel`
#
# The halo-model of the CIB requires a star-formation rate (SFR) model. Right now, we only have one SFR model implemented, based on the Maniyar et al. 2021 paper. In the future, we will implement flexibility to let the user define their own SFR model.
#
# The implemented SFR model also requires us to assume some HOD model for the CIB-emitting galaxies. Here, we assume that they follow the Zheng et al. 2005 paper.

# %%
from galCIB import SFRModel

# IR-emitting galaxies  HOD model 
hod_IR = get_hod_model("Zheng05", cosmo)

# Default SFR model
sfr_model = SFRModel(name="M21", hod=hod_IR, fsub=0.134)

# %% [markdown]
# # Step 7: Setup `SnuModel`
#
# Now we setup the SED model of the CIB field. We have two default models implemented, the non-parametric Maniyar et al. 2021 model, and the parametric Yan et al. 2023 model. These are implemented as `M21` and `Y23` in the package.

# %%
from galCIB import SnuModel

# Parametric Snu model (Y23)
snu_model_Y23 = SnuModel(name="Y23", cosmo=cosmo, survey=example_survey)

# Non parametric Snu model (M21)
# snu_model_M21 = SnuModel(name="M21", cosmo=cosmo, survey=example_survey)

# %% [markdown]
# # Step 8: Setup `CIBModel`

# %%
from galCIB import CIBModel 

# Initialize CIB model
cib_Y23 = CIBModel(sfr_model=sfr_model, 
                   snu_model=snu_model_Y23,
                   hod_IR=hod_IR
                   )

# %% [markdown]
# # Step 9: Setup `PkBuilder`

# %%
from galCIB import PkBuilder

# Y23 
pk_survey = PkBuilder(
                      hod_model=elg_hod_model,
                      cib_model=cib_Y23,
                      gal_prof_model=elg_sat_profile,
                      cib_prof_model=cib_sat_profile
                      )
# Out:
# INFO: GALAXY profile is mixed; CIB profile is static ('nfw').

# %% [markdown]
# # Step 10: Setup `AnalysisModel`

# %%
from galCIB import AnalysisModel

analysis = AnalysisModel(
                         survey=example_survey,
                         pk3d=pk_survey)

# %%
# parameters
theta_sfr = {}
theta_snu = {}
theta_IR  = {}

theta_cen = np.array([5.29784602, 11.79855648,0.59689872,  0.1]) # gamma, log10Mc, sigmaM, Ac
theta_sat = np.array([0.72366462,10**11.77445494, 10**13., -0.19832352]) # As, M0, M1, alpha_sat
theta_gal_prof = np.array([0.31701458,  5.21965594,  0.08534324]) # fexp, tau, lambda_NFW
theta_cib_prof = None

theta_sfr_M21 = np.array([0.63814394, # etamax
                          12.73, # Mpeak
                          1.28292033,  0.92461425, 2.38010441]) # sigmaM0, tauSFR, zc

theta_snu_M21 = None 
# theta_IR_M21 = np.array([11.35534397, -1.75224461, 0.4]) # mu0_Mmin, mup_Mmin, sigma_lnM
theta_IR_M21 = np.array([10.44, 0.4]) # Mmin, sigma_lnM

theta_sfr_Y23 = np.array([1, #eta_max 1 because Y23 cannot constrain this so the overall norm. goes to L0 in SED
                      11.78, # log10Mpeak
                      2.47,0.45,1.93]) #sigmaM0, tau, zc
theta_snu_Y23 = np.array([5e-14, 1.98,21.13, 0.21, 1.7]) # L0, beta_dust, T0, alpha_dust, gamma_dust
theta_IR_Y23 = np.array([11.47, 0.4]) # Mmin, sigma_lnM

theta_sfr['M21'] = theta_sfr_M21
theta_snu['M21'] = theta_snu_M21
theta_IR['M21'] = theta_IR_M21

theta_sfr['Y23'] = theta_sfr_Y23
theta_snu['Y23'] = theta_snu_Y23 
theta_IR['Y23'] = theta_IR_Y23

# %%
snu = 'Y23'

# %%
cgg, cgI, cII = analysis.update_cl(
        theta_cen=theta_cen,
                        theta_sat=theta_sat,
                        theta_gal_prof=theta_gal_prof,
                        theta_cib_prof=theta_cib_prof,
                        theta_sfr=theta_sfr[snu],
                        theta_snu=theta_snu[snu],
                        theta_IR_hod=theta_IR[snu],
                        theta_sn_gI=np.zeros(3),
                        theta_sn_II=np.zeros(6),
                        hmalpha=1)
# Out:
# /Users/tanveerk/research/Macintosh HD/Users/tkarim/research/galCIB/src/galCIB/galaxy/default_models.py:73: RuntimeWarning: invalid value encountered in power
#   Nsat = np.where(Mh-M0 < 0, 0, As * ((Mh-M0)/M1)**alpha_sat)

# %%
print(cgg.shape)
print(cgI.shape)
print(cII.shape)
# Out:
# (1900,)
# (3, 1900)
# (6, 1900)

# %%
plt.loglog(example_survey.ells, cgg, label='Cgg')
plt.loglog(example_survey.ells, cgI[2], label='CgI')
plt.loglog(example_survey.ells, cII[2], label='CII')
plt.xlabel(r'Multipole $\ell$')
plt.ylabel(r'$C_\ell$')
plt.legend(loc='best')
