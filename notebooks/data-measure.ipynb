# %% [markdown]
# Data Measurement of DESI Legacy Imaging Surveys ELGs and Lenz 2019 CIB Maps.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import healpy as hp
import copy
import pickle
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
plt.style.use("seaborn-v0_8-paper")

# %% [markdown]
# ## Impact of pixel window function
#
# It is known that `LMAX` above `NSIDE` starts feeling the impact of the pixel window function. This test assesses whether `hp.pixwin` can fix the issue, thereby allowing us to increase `LMAX`.

# %%
NSIDE = 1024
LMAX = NSIDE
ells = np.arange(3*NSIDE)
cl = np.ones(3*NSIDE-1)

# %%
# generate maps
tstmap = hp.synfast(cl, nside=NSIDE, pol=False)
tstmap_pw = hp.synfast(cl, nside=NSIDE, pol=False,
                    pixwin=True) # with pixel window

# %%
# calculate observe C_ells 


cl_npw = hp.anafast(tstmap,pol=False,
                    use_pixel_weights=True,
                    datapath=healpy_path)

cl_pw = hp.anafast(tstmap_pw,pol=False,
                    use_pixel_weights=True,
                    datapath=healpy_path)

# %%
plt.loglog(ells,cl_npw)
plt.loglog(ells,cl_pw)

# %%
pw = hp.pixwin(NSIDE,pol=False)

# %%
plt.loglog(ells,cl_npw)
plt.loglog(ells,cl_pw)
plt.loglog(ells,pw,c = 'k', ls = '--')

# %%
plt.loglog(ells,cl_npw, label=r'$D_{\ell}$ without pixwin')
plt.loglog(ells,cl_pw, label=r'$D_{\ell}$ with pixwin')
plt.loglog(ells,cl_pw/pw**2,
           label=r'$D_{\ell}/P_{\ell}^2$', alpha=0.5)
plt.loglog(ells,pw,c = 'k', ls = '--',
           label=r'$P_{\ell}$')
plt.legend(loc='best')

# %% [markdown]
# # Lenz+19 data
#
# In this section we measure the CIB-CIB power spectra based on the Lenz+19 data.
#
# The fiducial cut we use is $N_{\rm HI}$ column density masking of $2.5 \times 10^{20}$. We also consider other cuts for consistency.

# %% [markdown]
# ### Read in data

# %%
# parameters 

nulist = ['353', '545', '857']
NSIDE = 2048
LMAX = 1500

pixwin = hp.pixwin(NSIDE,pol=False)
ells = np.arange(LMAX)

data_folder = '/Users/tanveerk/research/research/research/galCIB/data/cib/cib-lenz19-data/'
nhi_cuts = ['1.5e+20_gp20',
    '1.8e+20_gp20',
    '2.0e+20_gp20',
    '2.5e+20_gp20',
    '3.0e+20_gp40',
    '4.0e+20_gp40']

healpy_data_path = '/Users/tanveerk/research/research/research/galCIB/data/healpy/'

# %% [markdown]
# ### $f_{\rm sky}$ as a function of $N_{\rm HI}$

# %%
# store fsky 
fsky = {}

for nu in nulist: 
    for nhi in nhi_cuts:
        mask_cib = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_bool.hpx.fits")
        fsky[f"{nu}+{nhi[:-9]}"] = mask_cib.sum()/mask_cib.size

# %%
fsky
# Out:
# {'353+1.5': np.float32(0.105635725),
#  '353+1.8': np.float32(0.14627402),
#  '353+2.0': np.float32(0.16381724),
#  '353+2.5': np.float32(0.18696125),
#  '353+3.0': np.float32(0.27573243),
#  '353+4.0': np.float32(0.34415826),
#  '545+1.5': np.float32(0.10519385),
#  '545+1.8': np.float32(0.1456821),
#  '545+2.0': np.float32(0.16314642),
#  '545+2.5': np.float32(0.18616438),
#  '545+3.0': np.float32(0.27443424),
#  '545+4.0': np.float32(0.3422587),
#  '857+1.5': np.float32(0.10413846),
#  '857+1.8': np.float32(0.1442279),
#  '857+2.0': np.float32(0.16150315),
#  '857+2.5': np.float32(0.18420394),
#  '857+3.0': np.float32(0.27149335),
#  '857+4.0': np.float32(0.33826843)}

# %% [markdown]
# We test the ranges $2.0 < N_{\rm HI} < 4.0 $ as this has the highest sky proportion.

# %% [markdown]
# ## Cross-$\nu$ Spectra
#
# Section F of 2210.01049 suggests that we should use the `fullmission` when $\nu \neq \nu'$.

# %%
cl_cibxcib_fullmission = {}
cl_cibxcib_fullmission_beam_corrected = {}
fsky_cross = {}

for nhi in nhi_cuts:
    for nu1 in nulist:
        for nu2 in nulist: 
            
            if nu1 == nu2: # ignore nu == nu' because of auto-noise
                continue 
            
            if int(nu1) > int(nu2): # ignore double counting 
                continue
            
            # folder location 
            floc1 = f"{data_folder}/{nu1}/{nhi}"
            floc2 = f"{data_folder}/{nu2}/{nhi}"
            
            # multiply by 1e6 to convert Jy to mJy 
            nu1_map = hp.read_map(f"{floc1}/cib_fullmission.hpx.fits")*1e6
            nu2_map = hp.read_map(f"{floc2}/cib_fullmission.hpx.fits")*1e6

            # read in relevant masks and calculate effective fsky
            mask_bool1 = hp.read_map(f"{floc1}/mask_bool.hpx.fits", dtype=bool)
            mask_bool2 = hp.read_map(f"{floc2}/mask_bool.hpx.fits", dtype=bool)
            mask_bool_eff = mask_bool1 * mask_bool2
            fsky_cross[f'{nu1}x{nu2}+{nhi[:-9]}'] = mask_bool_eff.sum()/len(mask_bool_eff)
            
            mask_apod1 = hp.read_map(f"{floc1}/mask_apod.hpx.fits")
            mask_apod2 = hp.read_map(f"{floc2}/mask_apod.hpx.fits")

            # calculate power spectra
            cl_fullmission = hp.anafast(
                map1=np.where(mask_bool1, nu1_map, 0.) * mask_apod1,
                map2=np.where(mask_bool2, nu2_map, 0.) * mask_apod2,
                datapath=healpy_data_path, 
                use_pixel_weights=True, 
                pol = False)
                
            cl_cibxcib_fullmission[f'{nu1}x{nu2}+{nhi[:-9]}'] = cl_fullmission
            
            # beam correction
            beam1 = pd.read_csv(f'{floc1}/windowfunctions.csv', comment='#')['Wl_eff'].values
            beam2 = pd.read_csv(f'{floc2}/windowfunctions.csv', comment='#')['Wl_eff'].values
            
            cl_cibxcib_fullmission_beam_corrected[f'{nu1}x{nu2}+{nhi[:-9]}'] = cl_cibxcib_fullmission[f'{nu1}x{nu2}+{nhi[:-9]}'][:LMAX]/(beam1*beam2)[:LMAX]

# %% [markdown]
# #### Measured $C (\ell)$ from Lenz+19

# %%
data_lenz19 = pd.read_csv(f"/Users/tkarim/research/galCIB/data/cib/cib-lenz19-data/Cl_CIB_T1T2.csv",
                          comment="#")

# %% [markdown]
# #### Comparison Plot

# %%
# frequencies to compare 

nu1 = '545'
nu2 = '857'

# %%
pw2048 = hp.pixwin(2048,pol=False)[:LMAX]

# %%
plt.plot(ells, 
         (cl_cibxcib_fullmission_beam_corrected[f'{nu1}x{nu2}+2.5']/fsky_cross[f'{nu1}x{nu2}+2.5'])/pw2048**2,
         label = r'$\tilde{D} (\ell)/f_{\rm sky}$',
         alpha = 0.6)

plt.plot(ells, 
         (cl_cibxcib_fullmission_beam_corrected[f'{nu1}x{nu2}+2.5']/fsky_cross[f'{nu1}x{nu2}+2.5']),
         label = r'$\tilde{D} (\ell)/f_{\rm sky} wpw$',
         alpha = 0.6)

plt.errorbar(data_lenz19['ell'], data_lenz19[f'{nu1}x{nu2}'], 
             yerr = data_lenz19[f'd{nu1}x{nu2}'],
             label = 'L19')

plt.xlabel(r"$\ell$", fontsize = 20)
plt.ylabel(r"$C (\ell)$", fontsize = 20)
plt.title(f'{nu1}x{nu2} + 2.5e-20')
plt.legend(loc='best')
plt.xlim([500, 1600])
plt.yscale("log")
plt.ylim([5e3, 8e4])
# Out:
# (5000.0, 80000.0)

# %% [markdown]
# ## Auto-$\nu$ Spectra
#
# As per Section F of 2210.01049, for same frequency we have to use odd-even to avoid correlated-noise bias.

# %%
cl_cibxcib_auto = {}
cl_cibxcib_auto_beam_corrected = {}
fsky_auto = {}

for nhi in nhi_cuts:
    for nu in nulist:
            
        # folder location 
        floc = f"{data_folder}/{nu}/{nhi}"
            
        # multiply by 1e6 to convert Jy to mJy 
        odd_map = hp.read_map(f"{floc}/cib_oddring.hpx.fits")*1e6
        even_map = hp.read_map(f"{floc}/cib_evenring.hpx.fits")*1e6

        # read in relevant masks and calculate effective fsky
        mask_bool = hp.read_map(f"{floc}/mask_bool.hpx.fits", dtype=bool)
        fsky_auto[f'{nu}x{nu}+{nhi[:-9]}'] = mask_bool.sum()/len(mask_bool)
        
        # apodized mask    
        mask_apod = hp.read_map(f"{floc}/mask_apod.hpx.fits")

        # calculate power spectra
        cl_auto = hp.anafast(
            map1=np.where(mask_bool, odd_map, 0.) * mask_apod,
            map2=np.where(mask_bool, even_map, 0.) * mask_apod,
            datapath=healpy_data_path, 
            use_pixel_weights=True, 
            pol = False)
            
        cl_cibxcib_auto[f'{nu}x{nu}+{nhi[:-9]}'] = cl_auto
            
        # beam correction
        beam = pd.read_csv(f'{floc}/windowfunctions.csv', comment='#')['Wl_eff'].values
            
        cl_cibxcib_auto_beam_corrected[f'{nu}x{nu}+{nhi[:-9]}'] = cl_cibxcib_auto[f'{nu}x{nu}+{nhi[:-9]}'][:LMAX]/(beam**2)[:LMAX]

# %%
nu = '857'

plt.plot(ells, 
         (cl_cibxcib_auto_beam_corrected[f'{nu}x{nu}+2.5']/fsky_auto[f'{nu}x{nu}+2.5'])/pw2048**2,
         label = r'$\tilde{D} (\ell)/f_{\rm sky}$',
         alpha = 0.6)

# plt.plot(ells, 
#          (cl_cibxcib_fullmission_beam_corrected[f'{nu1}x{nu2}+2.5']/fsky_cross[f'{nu1}x{nu2}+2.5']),
#          label = r'$\tilde{D} (\ell)/f_{\rm sky} wpw$',
#          alpha = 0.6)

plt.errorbar(data_lenz19['ell'], data_lenz19[f'{nu}x{nu}'], 
             yerr = data_lenz19[f'd{nu}x{nu}'],
             label = 'L19')

plt.xlabel(r"$\ell$", fontsize = 20)
plt.ylabel(r"$C (\ell)$", fontsize = 20)
plt.title(f'{nu}x{nu} + 2.5e-20')
plt.legend(loc='best')
# plt.xlim([500, 1600])
# plt.yscale("log")
# plt.ylim([5e3, 8e4])

# %%
(cl_cibxcib_fullmission_beam_corrected[f'{nu1}x{nu2}+2.5']/fsky_cross[f'{nu1}x{nu2}+2.5'])/pw2048**2,

# %%
cl_cibxcib_fullmission_beam_corrected
# Out:
# dict_keys(['353x545+1.5', '353x857+1.5', '545x857+1.5', '353x545+1.8', '353x857+1.8', '545x857+1.8', '353x545+2.0', '353x857+2.0', '545x857+2.0', '353x545+2.5', '353x857+2.5', '545x857+2.5', '353x545+3.0', '353x857+3.0', '545x857+3.0', '353x545+4.0', '353x857+4.0', '545x857+4.0'])

# %%
np.save("/Users/tkarim/research/galCIB/data/measurements/cl_cibxcib_fullmission_beam_corrected.npy",
        cl_cibxcib_fullmission_beam_corrected)

np.save("/Users/tkarim/research/galCIB/data/measurements/cl_cibxcib_auto_beam_corrected.npy",
        cl_cibxcib_auto_beam_corrected)

# %% [markdown]
# ## Rotate L19 to cross-correlate with DESI

# %% [markdown]
# Test 1: Rotate mask in alm space from G to C and `alm2map` with NSIDE = 1024.

# %%
nu = '545'
nhi = nhi_cuts[5]
print(nhi)

mask_apod = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_apod.hpx.fits")
mask_bool = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_bool.hpx.fits")
map_fm = hp.read_map(f"{data_folder}/{nu}/{nhi}/cib_fullmission.hpx.fits")
# Out:
# 4.0e+20_gp40

# %%
fsky = mask_bool.sum()/mask_bool.size
fsky
# Out:
# np.float32(0.3422587)

# %%
# effective map 
map_eff_cib = {}
nhi = nhi_cuts[5]
for nu in nulist:
    map_fm = hp.read_map(f"{data_folder}/{nu}/{nhi}/cib_fullmission.hpx.fits")
    mask_apod = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_apod.hpx.fits")
    mask_bool = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_bool.hpx.fits")
    map_eff = np.where(mask_bool, map_fm, 0.) * mask_apod
    map_eff_cib[f'{nu}_{nhi}'] = map_eff

# %%
nu = '353'
hp.mollview(map_eff_cib[f'{nu}_{nhi}'], title = f'{nu} + {nhi} + G + 2048',
            min=-0.1,max=0.1,cmap='coolwarm')

# %%
nu = '545'
hp.mollview(map_eff_cib[f'{nu}_{nhi}'], title = f'{nu} + {nhi} + G + 2048',
            min=-0.1,max=0.1,cmap='coolwarm')

# %%
from astropy.io import fits

# %%
dr2 = fits.open("/Users/tanveerk/research/research/research/galCIB/data/dr2/ELG_LOPnotqso_clustering.dat.fits")

ranCats = {}
for i in range(2):
    ranCats[i] = fits.open(f"/Users/tanveerk/research/research/research/galCIB/data/dr2/ELG_LOPnotqso_{i}_clustering.ran.fits")

# %%
# combine random catalogs into a single catalog
combined_ranCat = np.concatenate([ranCats[i][1].data for i in range(2)])

# %%
# plot redshift distribution of galaxies
plt.hist(dr2[1].data['Z'], bins=50, alpha=0.7, color='blue', density=True, label='Galaxies');
plt.hist(combined_ranCat['Z'], bins=50, alpha=0.7, color='orange', density=True, label='Random Catalog');
plt.xlabel('Redshift');
plt.ylabel('Density');
plt.title('Redshift Distribution');
plt.legend();
plt.show();

# %%
# group galaxies by redshift bins and create healpy maps for each bin
# bins are of width 0.2 from z = 0.8 to 1.6
z_bins = np.arange(0.8, 1.8, 0.2)

tomo_bins_data = {}
for i in range(len(z_bins)-1):
    z_min = np.round(z_bins[i], 1)
    z_max = np.round(z_bins[i+1], 1)
    tomo_bins_data[f'{z_min}-{z_max}'] = dr2[1].data[np.where((dr2[1].data['Z'] >= z_min) & (dr2[1].data['Z'] < z_max))[0]]
    
tomo_bins_rand = {}
for i in range(len(z_bins)-1):
    z_min = z_bins[i]
    z_max = z_bins[i+1]
    tomo_bins_rand[f'{z_min}-{z_max}'] = combined_ranCat[np.where((combined_ranCat['Z'] >= z_min) & (combined_ranCat['Z'] < z_max))[0]]

# %%
# plot histogram of galaxy counts
for z_bin, galaxies in tomo_bins_data.items():
    plt.hist(galaxies['Z'], bins=50, alpha=0.5, label=z_bin)
    print(f"Redshift bin: {z_bin}, Number of galaxies: {len(galaxies)}")
plt.xlabel('Redshift')
plt.ylabel('Number of Galaxies')
plt.title('Redshift Distribution of Galaxies in Tomographic Bins')
# Out:
# Redshift bin: 0.8-1.0, Number of galaxies: 1788304
# Redshift bin: 1.0-1.2, Number of galaxies: 1846180
# Redshift bin: 1.2-1.4, Number of galaxies: 1675902
# Redshift bin: 1.4-1.6, Number of galaxies: 1229302
# Text(0.5, 1.0, 'Redshift Distribution of Galaxies in Tomographic Bins')

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord

# %%
# convert to healpy maps for each tomographic bin
# nside = 2048
tomo_maps = {}
for z_bin, galaxies in tomo_bins_data.items():
    gal_l_bin = SkyCoord(ra=galaxies['RA']*u.degree, dec=galaxies['DEC']*u.degree, frame='icrs').galactic.l.degree
    gal_b_bin = SkyCoord(ra=galaxies['RA']*u.degree, dec=galaxies['DEC']*u.degree, frame='icrs').galactic.b.degree

    pixels_bin = hp.ang2pix(NSIDE, gal_l_bin, gal_b_bin, lonlat=True)
    gal_count_map_bin = np.bincount(pixels_bin, minlength=hp.nside2npix(NSIDE), weights=galaxies['WEIGHT'])

    tomo_maps[z_bin] = gal_count_map_bin

# %%
hp.mollview(tomo_maps['1.0-1.2'], title = 'galaxy count map', min=0, max=5, cmap='magma')

# %%
import pymaster as nmt

# %%
def construct_tomo_field(bin_idx, nside=2048):
    galaxies = tomo_bins_data[bin_idx]
    randoms = tomo_bins_rand[bin_idx]
    
    # rotate catalog to galactic coordinates
    gal_l_bin = SkyCoord(ra=galaxies['RA']*u.degree, dec=galaxies['DEC']*u.degree, frame='icrs').galactic.l.degree
    gal_b_bin = SkyCoord(ra=galaxies['RA']*u.degree, dec=galaxies['DEC']*u.degree, frame='icrs').galactic.b.degree
    
    ran_l_bin = SkyCoord(ra=randoms['RA']*u.degree, dec=randoms['DEC']*u.degree, frame='icrs').galactic.l.degree
    ran_b_bin = SkyCoord(ra=randoms['RA']*u.degree, dec=randoms['DEC']*u.degree, frame='icrs').galactic.b.degree
    
    # Catalog positions
    pos_data = np.array([gal_l_bin, gal_b_bin])
    pos_ran = np.array([ran_l_bin, ran_b_bin])

    # Catalog weights
    w_data = tomo_bins_data[bin_idx]['WEIGHT']
    w_rand = tomo_bins_rand[bin_idx]['WEIGHT']
    
    # Create NmtFieldCatalog for data and randoms
    lmax = 3 * nside - 1
    f_cat = nmt.NmtFieldCatalogClustering(pos_data, w_data, pos_ran, w_rand, lmax=lmax, lonlat=True)
    
    return f_cat

# %%
f_cat_tomo = {}
for z_bin, gal_map in tomo_maps.items():
    f_cat_tomo[z_bin] = construct_tomo_field(z_bin, nside=2048)

# %%
cib_fields = {}
for nu in nulist:
    map_eff = map_eff_cib[f'{nu}_{nhi}']
    cib_fields[f'{nu}'] = nmt.NmtField(np.ones_like(map_eff), [map_eff], n_iter=0)

# %%
# compute cl
nside = 2048
b = nmt.NmtBin.from_lmax_linear(3*nside-1, nlb=50)
leff = b.get_effective_ells()

def get_cl(f1, f2):
    w = nmt.NmtWorkspace.from_fields(f1, f2, b)
    pcl = nmt.compute_coupled_cell(f1, f2)
    cl = w.decouple_cell(pcl)
    return cl, pcl

# %%
# full cross-correlation power spectra

galaxies = dr2[1].data
randoms = combined_ranCat

# rotate catalog to galactic coordinates
gal_l_bin = SkyCoord(ra=galaxies['RA']*u.degree, dec=galaxies['DEC']*u.degree, frame='icrs').galactic.l.degree
gal_b_bin = SkyCoord(ra=galaxies['RA']*u.degree, dec=galaxies['DEC']*u.degree, frame='icrs').galactic.b.degree

ran_l_bin = SkyCoord(ra=randoms['RA']*u.degree, dec=randoms['DEC']*u.degree, frame='icrs').galactic.l.degree
ran_b_bin = SkyCoord(ra=randoms['RA']*u.degree, dec=randoms['DEC']*u.degree, frame='icrs').galactic.b.degree

# Catalog positions
pos_data = np.array([gal_l_bin, gal_b_bin])
pos_ran = np.array([ran_l_bin, ran_b_bin])

# Catalog weights
w_data = galaxies['WEIGHT']
w_rand = randoms['WEIGHT']

# Create NmtFieldCatalog for data and randoms
lmax = 3 * nside - 1
f_cat_full = nmt.NmtFieldCatalogClustering(pos_data, np.ones_like(w_data), pos_ran, np.ones_like(w_rand), lmax=lmax, lonlat=True)

# %%
cl_cib, pcl_cib = get_cl(cib_field, cib_field)

# %%
tst_cl_cib = hp.anafast(map_eff, pol=False, use_pixel_weights=True, datapath=healpy_data_path)

# %%
plt.loglog(tst_cl_cib)
plt.loglog(pcl_cib[0], ls='--')

# %%
plt.loglog(leff, cl_cib[0])

# %%
# total over all tomo 
gal_count_map = np.zeros(hp.nside2npix(nside))
# ran_count_map = np.zeros(hp.nside2npix(nside))

for z_bin, gal_map in tomo_maps.items():
    gal_count_map += gal_map
    # ran_count_map += tomo

# %%
hp.mollview(gal_count_map, title = 'galaxy count map', min=0, max=10, cmap='viridis')

# %%
# construct mask from random 

ran_l_bin = SkyCoord(ra=combined_ranCat['RA']*u.degree, dec=combined_ranCat['DEC']*u.degree, frame='icrs').galactic.l.degree
ran_b_bin = SkyCoord(ra=combined_ranCat['RA']*u.degree, dec=combined_ranCat['DEC']*u.degree, frame='icrs').galactic.b.degree

pixels_bin = hp.ang2pix(nside, ran_l_bin, ran_b_bin, lonlat=True)
ran_count_map_bin = np.bincount(pixels_bin, minlength=hp.nside2npix(nside), weights=combined_ranCat['WEIGHT'])

# %%
gal_mask = ran_count_map_bin > 0
delta_g = np.zeros(hp.nside2npix(nside))
delta_g[gal_mask] = gal_count_map[gal_mask]/np.mean(gal_count_map[gal_mask]) - 1

# %%
hp.mollview(delta_g, title = 'galaxy overdensity map', min=-1, max=1, cmap='coolwarm')

# %%
cl_gal_anafast = hp.anafast(delta_g, pol=False, use_pixel_weights=True, datapath=healpy_data_path)

# %%
cl_gal_nmt, pcl_gal_nmt = get_cl(f_cat_full, f_cat_full)

# %%
# Now create a NaMaster field
f_pix_gal_map = nmt.NmtField(gal_mask, [delta_g], n_iter=0)

# %%
pcl_gal_nmt_map = nmt.compute_coupled_cell(f_pix_gal_map, f_pix_gal_map)

# %%
plt.loglog(pcl_gal_nmt_map[0])
plt.loglog(pcl_gal_nmt[0])
plt.loglog(cl_gal_anafast, ls = '--')

# %%
cl_cross_anafast = hp.anafast(delta_g, map_eff, pol=False, use_pixel_weights=True, datapath=healpy_data_path)

# %%
plt.loglog(cl_cross_anafast)

# %%
cl_tomo_nmt = {}
for z_bin, f_cat in tomo_bins_data.items():
    cl_tomo_nmt[z_bin] = {}
    for nu in nulist:
        cib_field = cib_fields[f'{nu}']
        print(z_bin, nu)
    
        # construct mask from random 
        ran_l_bin = SkyCoord(ra=tomo_bins_rand[z_bin]['RA']*u.degree, dec=tomo_bins_rand[z_bin]['DEC']*u.degree, 
                            frame='icrs').galactic.l.degree
        ran_b_bin = SkyCoord(ra=tomo_bins_rand[z_bin]['RA']*u.degree, dec=tomo_bins_rand[z_bin]['DEC']*u.degree, 
                            frame='icrs').galactic.b.degree

        pixels_bin = hp.ang2pix(nside, ran_l_bin, ran_b_bin, lonlat=True)
        ran_count_map_bin = np.bincount(pixels_bin, minlength=hp.nside2npix(nside),
                                        weights=tomo_bins_rand[z_bin]['WEIGHT'])
        
        # construct galaxy overdensity map for this tomographic bin
        gal_mask = ran_count_map_bin > 0
        delta_g = np.zeros(hp.nside2npix(nside))
        delta_g[gal_mask] = tomo_maps[z_bin][gal_mask]/np.mean(tomo_maps[z_bin][gal_mask]) - 1

        # Now create a NaMaster field
        f_pix_gal_map = nmt.NmtField(gal_mask, [delta_g], n_iter=0)


        # Compute the mode-coupling matrix
        cl_tomo_nmt[z_bin][nu], _ = get_cl(f_pix_gal_map, cib_fields[nu])
# Out:
# 0.8-1.0 353
# 0.8-1.0 545
# 0.8-1.0 857
# 1.0-1.2 353
# 1.0-1.2 545
# 1.0-1.2 857
# 1.2-1.4 353
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 10
#       6 print(z_bin, nu)
#       8 # construct mask from random
#       9 ran_l_bin = SkyCoord(ra=tomo_bins_rand[z_bin]['RA']*u.degree, dec=tomo_bins_rand[z_bin]['DEC']*u.degree,
# ---> 10                     frame='icrs').galactic.l.degree
#      11 ran_b_bin = SkyCoord(ra=tomo_bins_rand[z_bin]['RA']*u.degree, dec=tomo_bins_rand[z_bin]['DEC']*u.degree,
#      12                     frame='icrs').galactic.b.degree
#      14 pixels_bin = hp.ang2pix(nside, ran_l_bin, ran_b_bin, lonlat=True)
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/coordinates/sky_coordinate.py:743, in SkyCoord.__getattr__(self, attr)
#     741     frame_cls = frame_transform_graph.lookup_name(attr)
#     742     if frame_cls is not None and self.frame.is_transformable_to(frame_cls):
# --> 743         return self.transform_to(attr)
#     745 # Call __getattribute__; this will give correct exception.
#     746 return self.__getattribute__(attr)
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/coordinates/sky_coordinate.py:551, in SkyCoord.transform_to(self, frame, merge_attributes)
#     547 generic_frame = GenericFrame(frame_kwargs)
#     549 # Do the transformation, returning a coordinate frame of the desired
#     550 # final type (not generic).
# --> 551 new_coord = trans(self.frame, generic_frame)
#     553 # Finally make the new SkyCoord object from the `new_coord` and
#     554 # remaining frame_kwargs that are not frame_attributes in `new_coord`.
#     555 for attr in set(new_coord.frame_attributes) & set(frame_kwargs.keys()):
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/coordinates/transformations/composite.py:113, in CompositeTransform.__call__(self, fromcoord, toframe)
#     110             frattrs[inter_frame_attr_nm] = attr
#     112     curr_toframe = t.tosys(**frattrs)
# --> 113     curr_coord = t(curr_coord, curr_toframe)
#     115 # this is safe even in the case where self.transforms is empty, because
#     116 # coordinate objects are immutable, so copying is not needed
#     117 return curr_coord
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/coordinates/transformations/affine.py:205, in BaseAffineTransform.__call__(self, fromcoord, toframe)
#     203 def __call__(self, fromcoord, toframe):
#     204     params = self._affine_params(fromcoord, toframe)
# --> 205     newrep = self._apply_transform(fromcoord, *params)
#     206     return toframe.realize_frame(newrep)
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/coordinates/transformations/affine.py:119, in BaseAffineTransform._apply_transform(self, fromcoord, matrix, offset)
#     115     data = data.without_differentials()
#     117 # Convert the representation and differentials to cartesian without
#     118 # having them attached to a frame
# --> 119 rep = data.to_cartesian()
#     120 diffs = {
#     121     k: diff.represent_as(CartesianDifferential, data)
#     122     for k, diff in data.differentials.items()
#     123 }
#     124 rep = rep.with_differentials(diffs)
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/coordinates/representation/spherical.py:104, in UnitSphericalRepresentation.to_cartesian(self)
#      99 """
#     100 Converts spherical polar coordinates to 3D rectangular cartesian
#     101 coordinates.
#     102 """
#     103 # erfa s2c: Convert [unit]spherical coordinates to Cartesian.
# --> 104 p = erfa_ufunc.s2c(self.lon, self.lat)
#     105 return CartesianRepresentation(p, xyz_axis=-1, copy=False)
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/coordinates/angles/core.py:750, in Longitude.__array_ufunc__(self, *args, **kwargs)
#     749 def __array_ufunc__(self, *args, **kwargs):
# --> 750     results = super().__array_ufunc__(*args, **kwargs)
#     751     return _no_angle_subclass(results)
#
# File /opt/anaconda3/envs/cib/lib/python3.13/site-packages/astropy/units/quantity.py:645, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     643 for input_, converter in zip(inputs, converters):
#     644     input_ = getattr(input_, "value", input_)
# --> 645     arrays.append(converter(input_) if converter else input_)
#     647 # Call our superclass's __array_ufunc__
#     648 result = super().__array_ufunc__(function, method, *arrays, **kwargs)
#
# KeyboardInterrupt:

# %%
z_bin='1.4-1.6'
z_bin_rand = '1.4-1.5999999999999999'
cl_tomo_nmt[z_bin] = {}

for nu in nulist:
    cib_field = cib_fields[f'{nu}']
    print(z_bin, nu)

    # construct mask from random 
    ran_l_bin = SkyCoord(ra=tomo_bins_rand[z_bin_rand]['RA']*u.degree, dec=tomo_bins_rand[z_bin_rand]['DEC']*u.degree, 
                        frame='icrs').galactic.l.degree
    ran_b_bin = SkyCoord(ra=tomo_bins_rand[z_bin_rand]['RA']*u.degree, dec=tomo_bins_rand[z_bin_rand]['DEC']*u.degree, 
                        frame='icrs').galactic.b.degree

    pixels_bin = hp.ang2pix(nside, ran_l_bin, ran_b_bin, lonlat=True)
    ran_count_map_bin = np.bincount(pixels_bin, minlength=hp.nside2npix(nside),
                                    weights=tomo_bins_rand[z_bin_rand]['WEIGHT'])
    
    # construct galaxy overdensity map for this tomographic bin
    gal_mask = ran_count_map_bin > 0
    delta_g = np.zeros(hp.nside2npix(nside))
    delta_g[gal_mask] = tomo_maps[z_bin][gal_mask]/np.mean(tomo_maps[z_bin][gal_mask]) - 1

    # Now create a NaMaster field
    f_pix_gal_map = nmt.NmtField(gal_mask, [delta_g], n_iter=0)


    # Compute the mode-coupling matrix
    cl_tomo_nmt[z_bin][nu], _ = get_cl(f_pix_gal_map, cib_fields[nu])
# Out:
# 1.4-1.6 353
# 1.4-1.6 545
# 1.4-1.6 857

# %%
tomo_bins_rand.keys()
# Out:
# dict_keys(['0.8-1.0', '1.0-1.2', '1.2-1.4', '1.4-1.5999999999999999'])

# %%
cl_tomo_nmt['1.4-1.6']['353'][0]
# Out:
# array([ 2.62725749e-07,  2.64831912e-08,  2.24657563e-08,  2.13212887e-08,
#         1.22741455e-08,  9.54043520e-09,  6.85398422e-09,  8.32825705e-09,
#         6.03265478e-09,  5.65023136e-09,  4.33375593e-09,  4.00535797e-09,
#         3.36329813e-09,  2.99273833e-09,  1.62681684e-09,  2.69582073e-09,
#         2.76092530e-09,  2.11617413e-09,  2.07577836e-09,  9.33799719e-10,
#         6.20835809e-10,  1.00869605e-09,  1.36838723e-09,  4.58089657e-10,
#         1.45697947e-09,  1.46493650e-09,  2.12014009e-09,  1.08060723e-09,
#         6.01480131e-10,  6.67796711e-10,  1.31651296e-09,  2.74391562e-10,
#        -2.35663406e-11,  4.73808765e-10,  5.90677678e-10,  2.61477765e-11,
#         4.06224043e-10, -1.42328326e-11, -3.77671142e-12,  3.65233805e-10,
#         4.37488480e-10,  5.30231420e-10,  6.10387280e-10,  5.40672124e-10,
#         3.92552510e-10, -3.49125005e-10,  6.63666105e-10,  1.78124821e-10,
#        -1.46661286e-10,  3.39550912e-10,  3.22201143e-11,  3.54670022e-10,
#         1.84714397e-10, -7.57558629e-11,  2.50000068e-10,  8.52711605e-11,
#         7.90047479e-11, -1.28674078e-10,  1.81624382e-10,  1.68840501e-10,
#         1.39828442e-10, -5.41546512e-11,  4.22202177e-10,  1.81726113e-10,
#         3.74362071e-10,  4.56380493e-11,  6.19820092e-11, -4.87769994e-13,
#         2.56397126e-10,  1.78380254e-10, -2.22069623e-10,  1.73779214e-10,
#        -2.50728043e-10,  1.53933956e-10,  2.65484134e-10, -4.33409905e-11,
#        -6.67920840e-11,  1.49762229e-10, -2.86212201e-11, -1.32981690e-11,
#        -1.64416154e-11,  9.08628568e-12,  9.09455830e-12,  1.31996349e-11,
#        -4.27290119e-12, -6.44276258e-12,  3.02179538e-12,  8.61058842e-12,
#        -1.20403062e-12,  2.39187860e-12, -2.00523811e-12, -8.29251472e-12,
#         3.00843572e-13, -2.40063054e-12, -1.08292993e-11, -2.77511279e-12,
#         1.32935521e-12, -7.85304143e-12, -3.28369421e-12, -8.16208944e-14,
#        -2.72050437e-12,  5.81583122e-12,  3.95799726e-12, -4.21679425e-12,
#         3.88717117e-12,  1.57447230e-12,  9.75222088e-13,  8.81703666e-13,
#        -9.39064415e-13,  2.82659185e-12,  1.24806126e-12, -2.38149696e-12,
#         4.76005651e-12,  1.37561838e-12, -8.11035892e-13,  9.80425028e-12,
#         1.97129824e-12,  7.47773679e-12, -5.79549457e-12, -8.10100209e-12,
#         4.55704164e-12, -3.48431177e-12])

# %%
for bin_idx in ['0.8-1.0', '1.0-1.2', '1.4-1.6']:
    for nu in nulist:
        plt.scatter(leff, cl_tomo_nmt[bin_idx][nu][0], label = f'{bin_idx}_{nu}')
    
plt.legend(loc='best')
plt.xscale('log')
plt.yscale('log')
plt.title("545")
# plt.xlim([10, 2500])
# Out:
# Text(0.5, 1.0, '545')

# %%
bin_idx = '0.8-1.0'
for nu in nulist:
    plt.scatter(leff, cl_tomo_nmt[bin_idx][nu][0], label = f'{nu}')
plt.xscale('log')
plt.yscale('log')
plt.title(f"{bin_idx}")
plt.legend()

# %%
bin_idx = '1.0-1.2'
for nu in nulist:
    plt.scatter(leff, cl_tomo_nmt[bin_idx][nu][0], label = f'{nu}')
plt.xscale('log')
plt.yscale('log')
plt.title(f"{bin_idx}")
plt.legend()

# %%
nu = '857'
for bin_idx in ['0.8-1.0', '1.0-1.2', '1.4-1.6']:
    plt.scatter(leff, cl_tomo_nmt[bin_idx][nu][0], label = f'{bin_idx}')
plt.xscale('log')
plt.yscale('log')
plt.title(f"{nu}")
plt.legend()

# %%
nu = '353'
for bin_idx in ['0.8-1.0', '1.0-1.2', '1.4-1.6']:
    plt.scatter(leff, cl_tomo_nmt[bin_idx][nu][0], label = f'{bin_idx}')
plt.xscale('log')
plt.yscale('log')
plt.title(f"{nu}")
plt.legend()

# %%
nu = '545'
for bin_idx in ['0.8-1.0', '1.0-1.2', '1.4-1.6']:
    plt.scatter(leff, cl_tomo_nmt[bin_idx][nu][0], label = f'{bin_idx}')
plt.xscale('log')
plt.yscale('log')
plt.title(f"{nu}")
plt.legend()

# %%
for bin_idx in cl_tomo_nmt.keys():
    plt.scatter(leff, cl_tomo_nmt[bin_idx][0], label = bin_idx)
    
plt.legend(loc='best')
plt.xscale('log')
plt.yscale('log')
plt.title("545")
# plt.xlim([10, 2500])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 for bin_idx in cl_tomo_nmt.keys():
# ----> 2     plt.scatter(leff, cl_tomo_nmt[bin_idx][0], label = bin_idx)
#       4 plt.legend(loc='best')
#       5 plt.xscale('log')
#
# KeyError: 0

# %%
for bin_idx in cl_tomo_nmt.keys():
    plt.scatter(leff, cl_tomo_nmt[bin_idx][0], label = bin_idx)
    
plt.legend(loc='best')
plt.xscale('log')
plt.yscale('log')
# plt.xlim([10, 2500])

# %%
for bin_idx in cl_tomo_nmt.keys():
    plt.semilogx(leff, cl_tomo_nmt[bin_idx][0]/cl_tomo_nmt['0.8-1.0'][0], label = bin_idx)
    
plt.legend(loc='best')
plt.xlim([10, 1500])
plt.ylim([0, 5])
# Out:
# (0.0, 5.0)

# %%
for bin_idx in cl_tomo_hp.keys():
    plt.loglog(cl_tomo_hp[bin_idx], label = bin_idx)
    
plt.legend(loc='best')

# %%
# plot the cross-correlation power spectra for each tomographic bin
plt.figure(figsize=(10, 6))
for z_bin, cl in cl_tomo.items():
    plt.semilogx(leff, cl[0], label=f'Tomographic Bin {z_bin}')
plt.xlabel(r'$\ell$', fontsize=20)
plt.ylabel(r'$C_{\ell}^{\rm gal \times CIB}$', fontsize=20)
plt.title('Cross-Correlation Power Spectra for Tomographic Bins')
plt.legend(loc='best')

# %%
# calculate native Cl 

Cl_true = hp.anafast(map_eff,
                     pol=False,
                     use_pixel_weights=True,
                     datapath=healpy_data_path)

# %%
LMIN=50; LMAX = 1500
ells = np.arange(LMIN, LMAX)

# %%
plt.loglog(ells,Cl_true[LMIN:LMAX])
plt.title("353 + 2.5e-20 + G + 2048")
# Out:
# Text(0.5, 1.0, '353 + 2.5e-20 + G + 2048')

# %%
mask_apod = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_apod.hpx.fits")
mask_bool = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_bool.hpx.fits")
map_fm = hp.read_map(f"{data_folder}/{nu}/{nhi}/cib_fullmission.hpx.fits")

# %%
healpy_data_path = '/Users/tanveerk/research/research/research/galCIB/data/healpy/'

# %%
# convert map to alm
alm_map_eff_g_2048 = hp.map2alm(map_eff,pol=False,
                         use_pixel_weights=True,
                         datapath=healpy_data_path)

# %%
# rotate alm
from healpy.rotator import Rotator
r = Rotator(coord=['G','C'])
alm_map_eff_c_2048 = r.rotate_alm(alm_map_eff_g_2048)

# %%
# convert alm to map 
map_eff_c_1024 = hp.alm2map(alm_map_eff_c_2048,
                            nside=1024,pol=False)

# %%
# calculate Cl from this rotation 

Cl_rotated_from_eff_to_c_1024 = hp.anafast(map_eff_c_1024,
                                           pol=False,
                                           use_pixel_weights=True,
                                           datapath=healpy_data_path)

# %%
plt.loglog(ells,Cl_true[LMIN:LMAX],
           label="353 + 2.5e-20 + G + 2048")
plt.loglog(ells,Cl_rotated_from_eff_to_c_1024[LMIN:LMAX],
           label='Eff rotated to C + 1024',
           alpha=0.3)

# %%
# ratio plot 

ratio = Cl_rotated_from_eff_to_c_1024[LMIN:LMAX]/Cl_true[LMIN:LMAX]
plt.loglog(ells, ratio)
plt.title("353 + 2.5e-20 + G + 2048")
# Out:
# Text(0.5, 1.0, '353 + 2.5e-20 + G + 2048')

# %%
hp.mollview(map_eff_c_1024, rot=-85,
            min=-0.1,max=0.1,cmap='coolwarm',
            title='353+2.5e-20+C+1024')

# %%
tst = hp.mask_bad(map_eff_c_1024,
            badval=0,atol=1e-5)

# %%
hp.mollview(tst, rot=-85)

# %%
mask_bool_pixel_rot = r.rotate_map_pixel(mask_bool)

# %%
hp.mollview(mask_bool_pixel_rot, rot = -85)

# %%
mask_bool_pixel_rot.sum()/mask_bool_pixel_rot.size
# Out:
# np.float64(0.18696126071019373)

# %%
mask_bool.sum()/mask_bool.size
# Out:
# np.float32(0.18696125)

# %%
mask_bool_pixel_rot_udgrade_1024 = hp.ud_grade(mask_bool_pixel_rot,
                                               1024)
# rebinarize
mask_bool_pixel_rot_udgrade_1024 = np.where(mask_bool_pixel_rot_udgrade_1024>0.95,
                                            1,0)

# %%
hp.mollview(mask_bool_pixel_rot_udgrade_1024,rot=-85)

# %%
fsky_ud = mask_bool_pixel_rot_udgrade_1024.sum()/mask_bool_pixel_rot_udgrade_1024.size
print(f'fsky rotated in C + udgrade 1024 = {fsky_ud}')

fsky_rot = mask_bool_pixel_rot.sum()/mask_bool_pixel_rot.size
print(f'fsky rotated in C + 2048 = {fsky_rot}')

fsky_true = mask_bool.sum()/mask_bool.size
print(f'fsky native in G + 2048 = {fsky_true}')
# Out:
# fsky rotated in C + udgrade 1024 = 0.18420648574829102
# fsky rotated in C + 2048 = 0.18696126071019373
# fsky native in G + 2048 = 0.18696124851703644

# %%
import pymaster as nmt

# %%
# reapodize 

mask_apod_rot_1024 = nmt.mask_apodization(mask_bool_pixel_rot_udgrade_1024, 
                                          0.25, "C2")

# %%
map_eff_c_1024_re_apod = np.where(mask_bool_pixel_rot_udgrade_1024,
                                  map_eff_c_1024,
                                  0)*mask_apod_rot_1024

# %%
hp.mollview(map_eff_c_1024_re_apod,
            rot=-85,
            min=-0.1,max=0.1,
            cmap='coolwarm')

# %%
map_eff_c_1024_re_apod.min()
# Out:
# np.float64(-0.14553705324287544)

# %%
Cl_c_1024_re_apod = hp.anafast(map_eff_c_1024_re_apod,
                               pol=False,
                               use_pixel_weights=True,
                               datapath=healpy_data_path)

# %%
plt.loglog(ells,Cl_true[LMIN:LMAX],
           label="353 + 2.5e-20 + G + 2048")
plt.loglog(ells,Cl_rotated_from_eff_to_c_1024[LMIN:LMAX],
           label='Eff rotated to C + 1024',
           alpha=0.3)

plt.loglog(ells,Cl_c_1024_re_apod[LMIN:LMAX],
           label='C + 1024 re apod',
           alpha=0.3)

# %%
# ratio plot 

ratio = Cl_c_1024_re_apod[LMIN:LMAX]/Cl_true[LMIN:LMAX]
plt.loglog(ells, ratio * fsky_true/fsky_ud)
plt.title("re apod compare with true")
# Out:
# Text(0.5, 1.0, 're apod compare with true')

# %%
fsky_true/fsky_ud
# Out:
# np.float64(1.0149547544841047)

# %%
ratio.mean()
# Out:
# np.float64(0.9757253167469426)

# %%
plt.hist(ratio * fsky_true/fsky_ud,
         bins=100);
plt.title("Comparison of power spectra")
# Out:
# Text(0.5, 1.0, 'Comparison of power spectra')

# %%
map_eff_c_1024_re_apod[~mask_bool_pixel_rot_udgrade_1024.astype(bool)] = hp.UNSEEN

# %%
hp.mollview(map_eff_c_1024_re_apod,
            rot=-85,
            min=-0.1,max=0.1,
            cmap='coolwarm')

# %%
Cl_c_1024_re_apod_UNSEEN = hp.anafast(map_eff_c_1024_re_apod,
                               pol=False,
                               use_pixel_weights=True,
                               datapath=healpy_data_path)

# %%
# ratio plot 

ratio = Cl_c_1024_re_apod_UNSEEN[LMIN:LMAX]/Cl_true[LMIN:LMAX]
plt.loglog(ells, ratio * fsky_true/fsky_ud)
plt.title("re apod compare with true")
# Out:
# Text(0.5, 1.0, 're apod compare with true')

# %%
# plt.loglog(ells,Cl_true[LMIN:LMAX],
#            label="353 + 2.5e-20 + G + 2048")
# plt.loglog(ells,Cl_rotated_from_eff_to_c_1024[LMIN:LMAX],
#            label='Eff rotated to C + 1024',
#            alpha=0.3)

plt.loglog(ells,Cl_c_1024_re_apod[LMIN:LMAX],
           label='C + 1024 re apod',
           alpha=0.3)

plt.loglog(ells,Cl_c_1024_re_apod_UNSEEN[LMIN:LMAX],
           label='C + 1024 re apod',
           alpha=0.3)

# %%
# mask for CIB footprint
cibmasks_gal = {}

for nu in nulist:
    for nhi in nhi_cuts:
        cibmasks_gal[f'{nu}+{nhi[:-9]}'] = hp.read_map(f"{data_folder}/{nu}/{nhi}/mask_bool.hpx.fits")

# %% [markdown]
# As an example use 353 with 1.5 cut.

# %%
hp.mollview(cibmasks_gal['353+1.5'],
            title='353 + 1.5e-20')

# %%
nmt.__version__
# Out:
# '2.2.1'

# %%
print(f"fsky in native resolution = {cibmasks_gal['353+1.5'].sum()/cibmasks_gal['353+1.5'].size}")
# Out:
# fsky in native resolution = 0.10563572247823079

# %%
# apply rotation
mask_g_2048 = cibmasks_gal['353+1.5']
mask_c_2048 = r.rotate_map_alms(mask_g_2048, 
                                use_pixel_weights=True, 
                                datapath=healpy_data_path)

# %% [markdown]
# Check fsky comparison

# %%
hp.mollview(mask_c_2048, rot=-85,
            title='353+1.5 in C + 2048')

# %%
plt.hist(mask_c_2048[mask_c_2048<0.5],bins=100);
plt.yscale("log")

# %%
# measure Cls and compare 

Cl_g_2048 = hp.anafast(mask_g_2048,pol=False,
                       use_pixel_weights=True,
                       datapath=healpy_data_path)

# %%
# rotate CIB masks
r = hp.Rotator(coord=['G','C']) #define rotator class from Eq. Coord. to Gal. Coord
healpy_data_path = '/Users/tkarim/research/galCIB/data/healpy/'

# CIB mask in equatorial
cibmasks_eq = {}

for nu in nulist:
    print(nu)
    for nhi in nhi_cuts:
        cibmask_alm = hp.map2alm(cibmasks_gal[f'{nu}+{nhi[:-9]}'], 
                                 pol = False)
        cibmask_alm_eq = r.rotate_alm(cibmask_alm)
        cibmasks_eq[f'{nu}+{nhi[:-9]}'] = hp.alm2map(cibmask_alm_eq, 
                                                     nside=NSIDE, 
                                                     pol = False)
# Out:
# 353
# 545
# 857

# %%
hp.mollview(cibmasks_gal['353+2.0'])

# %%
hp.mollview(cibmasks_eq['353+2.0'],
            rot=-85)

# %%
tstg = hp.anafast(cibmasks_gal['545+2.0'],
                  pol=False,
                  use_pixel_weights=True,
                  datapath=healpy_data_path)

tste = hp.anafast(cibmasks_eq['545+2.0'],
                  pol=False,
                  use_pixel_weights=True,
                  datapath=healpy_data_path)

# %%
LMIN=50
tste_pw = tste[LMIN:LMAX]#/pw1024[:LMAX]**2
tstg_pw = tstg[LMIN:LMAX]#/pw2048[:LMAX]**2
plt.semilogx(ells[LMIN:LMAX],
           (tste_pw/tstg_pw - 1))

# %%
tstg[LMIN:LMAX]/pw2048[LMIN:LMAX]**2
# Out:
# array([3.11972572e-05, 2.29121681e-05, 2.02432557e-05, ...,
#        3.90640337e-09, 3.86512755e-09, 3.79461167e-09])

# %%
plt.semilogx(ells[LMIN:LMAX],
             ((tste/pw1024**2)[LMIN:LMAX])/(tstg[LMIN:LMAX]/pw2048[LMIN:LMAX]**2)
)

# %%
# rotate CIB masks
r = hp.Rotator(coord=['G','C']) #define rotator class from Eq. Coord. to Gal. Coord
healpy_data_path = '/Users/tkarim/research/galCIB/data/healpy/'

# CIB mask in equatorial
cibmasks_eq = {}

for nu in nulist:
    print(nu)
    for nhi in nhi_cuts:
        cibmask_alm = hp.map2alm(cibmasks_gal[f'{nu}+{nhi[:-9]}'], 
                                 pol = False)
        cibmask_alm_eq = r.rotate_alm(cibmask_alm)
        cibmasks_eq[f'{nu}+{nhi[:-9]}'] = hp.alm2map(cibmask_alm_eq, 
                                                     nside=NSIDE, 
                                                     pol = False)

# %%
nu = '353'
nhi = nhi_cuts[3]
print(nhi)
tmp_alm = hp.map2alm(
    cibmasks_gal[f'{nu}+{nhi[:-9]}'], 
    pol = False,
    use_pixel_weights=True,
    datapath=healpy_data_path,
    lmax=LMAX)
# Out:
# 2.5e+20_gp20

# %%
tmp_gal_1024 = hp.alm2map(tmp_alm, 
                          nside=NSIDE, 
                        pol = False)

# %%
tmp_cl_gal_1024 = hp.anafast(tmp_gal_1024,
                             pol=False,
                             use_pixel_weights=True,
                             datapath=healpy_data_path)

tmp_cl_gal_2048 = hp.anafast(cibmasks_gal[f'{nu}+{nhi[:-9]}'],
                             pol=False,
                             use_pixel_weights=True,
                             datapath=healpy_data_path)

# %%
plt.loglog(
    tmp_cl_gal_1024[:LMAX]/tmp_cl_gal_2048[:LMAX]
    )

# %%
tmp_alm_eq = r.rotate_alm(tmp_alm)
tmp_alm_eq_lmax = r.rotate_alm(tmp_alm,
                          lmax=LMAX)

# %%
tmp_eq_1024 = hp.alm2map(tmp_alm_eq, 
                          nside=NSIDE, 
                        pol = False)

tmp_eq_1024_lmax = hp.alm2map(tmp_alm_eq_lmax, 
                          nside=NSIDE, 
                        pol = False)

# %%
tmp_cl_eq_1024 = hp.anafast(tmp_eq_1024,
                             pol=False,
                             use_pixel_weights=True,
                             datapath=healpy_data_path)

tmp_cl_eq_1024_lmax = hp.anafast(tmp_eq_1024_lmax,
                             pol=False,
                             use_pixel_weights=True,
                             datapath=healpy_data_path)

# %%
plt.loglog(
    tmp_cl_eq_1024_lmax[:LMAX]/tmp_cl_gal_2048[:LMAX]
    )

# %%
tmp_cl_eq_1024_lmax[:LMAX]/tmp_cl_gal_2048[:LMAX]
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
cibmasks_eq['']
# Out:
# {'353+1.5': array([-1.97555154e-04, -1.82821120e-04, -4.78719987e-05, ...,
#         -1.35278567e-04, -4.75092408e-04,  2.39790285e-04]),
#  '353+1.8': array([ 4.35035461e-04, -9.95854788e-05, -3.61539945e-04, ...,
#          2.18685136e-04,  4.02106990e-04,  3.88701119e-04]),
#  '353+2.0': array([-1.48455927e-04, -5.36122066e-05,  2.75008710e-04, ...,
#          2.91349337e-04,  7.50758750e-06,  2.80907053e-04]),
#  '353+2.5': array([ 4.00929627e-05, -3.37660581e-05, -8.44339641e-05, ...,
#         -2.05681558e-04, -7.77154512e-05, -6.37713045e-05]),
#  '353+3.0': array([-0.00028435, -0.0014344 ,  0.00065506, ..., -0.00053306,
#         -0.00025317, -0.00048537]),
#  '353+4.0': array([-0.00061101, -0.00037025,  0.00067484, ...,  0.00010832,
#         -0.00073324, -0.00028332]),
#  '545+1.5': array([-1.46498911e-04, -1.68165330e-04, -3.86044560e-05, ...,
#         -8.46308449e-05, -4.94541758e-04,  1.44225616e-04]),
#  '545+1.8': array([ 0.00055552, -0.00013467, -0.00049006, ...,  0.00031777,
#          0.00034523,  0.00032437]),
#  '545+2.0': array([ 2.12932021e-05, -1.54465995e-04,  1.01458406e-04, ...,
#          4.07981448e-04, -9.70274368e-05,  1.98069080e-04]),
#  '545+2.5': array([ 2.35995062e-04, -1.67896655e-04, -2.38698911e-04, ...,
#         -1.88891039e-05, -1.77584540e-04, -9.71556383e-05]),
#  '545+3.0': array([-4.25165946e-05, -1.08212735e-03,  4.77832094e-04, ...,
#         -2.21319803e-04, -1.28464542e-04, -3.15808354e-04]),
#  '545+4.0': array([-0.00030775,  0.00023281,  0.00057124, ...,  0.00030254,
#         -0.000696  , -0.00026974]),
#  '857+1.5': array([-2.75942449e-04, -2.99424635e-04, -2.11875255e-04, ...,
#         -6.10469346e-05, -6.24042372e-04,  1.51309382e-04]),
#  '857+1.8': array([ 0.00041329, -0.00036127, -0.00070773, ...,  0.00033757,
#          0.00038444,  0.00046078]),
#  '857+2.0': array([-6.93692973e-07, -4.77292042e-04, -2.31767740e-04, ...,
#          3.67603179e-04, -9.57123772e-05,  2.74288785e-04]),
#  '857+2.5': array([ 7.36579878e-05, -3.33512078e-04, -3.70288595e-04, ...,
#         -1.21339730e-04, -2.44005112e-04, -1.46749123e-05]),
#  '857+3.0': array([-5.26207433e-04, -1.39990495e-03,  4.57628074e-05, ...,
#         -2.67076798e-04, -1.43128591e-04, -3.52800200e-04]),
#  '857+4.0': array([-2.14028998e-04, -3.56065692e-04,  1.70098529e-04, ...,
#          4.64405175e-05, -8.18466111e-04, -1.76775436e-04])}

# %%
pw1024 = hp.pixwin(1024,pol=False,
                   )
pw2048 = hp.pixwin(2048,pol=False,
                   )

# %%
plt.loglog(pw2048**2,label='2048')
plt.loglog(pw1024**2,c='k',
           label='1024')
plt.axvline(1024)
plt.axhline(0.99)
plt.legend(loc='best')

# %%
nside = 1024


def psinc(nside, ells):
    thetar = np.sqrt(4*np.pi/(12*nside**2))
    
    res =  np.sinc(thetar*ells/(2*np.pi))   
    
    return res

# %%
t1024 = psinc(1024,ells)
t2048 = psinc(2048,ells)

# %%
plt.loglog(t1024)
plt.loglog(t2048)
plt.axvline(1024)

plt.loglog(pw2048,label='2048',
           ls='--')

# %% [markdown]
# ## Full comparison with `NaMaster`

# %% [markdown]
# We observe that the agreement is fairly good, when measurement is corrected for $f_{\rm sky}$. However for full comparison, we use `NaMaster`.

# %%
import pymaster as nmt

# %% [markdown]
# ### Estimate $\tilde{C} (\ell)$ using `NaMaster`

# %%
# setup NmtField object

# extract apodized masks 

mask_bool1 = hp.read_map(f"{data_folder}/{nu1}/2.5e+20_gp20/mask_bool.hpx.fits", dtype=bool)
mask_bool2 = hp.read_map(f"{data_folder}/{nu2}/2.5e+20_gp20/mask_bool.hpx.fits", dtype=bool)

mask_apod1 = hp.read_map(f"{data_folder}/{nu1}/2.5e+20_gp20/mask_apod.hpx.fits")
mask_apod2 = hp.read_map(f"{data_folder}/{nu2}/2.5e+20_gp20/mask_apod.hpx.fits")

mask_nu1 = np.where(mask_bool1, 1, 0) * mask_apod1
mask_nu2 = np.where(mask_bool2, 1, 0) * mask_apod2

# extract data

nu1_map = hp.read_map(f"{data_folder}/{nu1}/2.5e+20_gp20/cib_fullmission.hpx.fits")*1e6
nu2_map = hp.read_map(f"{data_folder}/{nu2}/2.5e+20_gp20/cib_fullmission.hpx.fits")*1e6

# remove nans
nu1_map = np.where(mask_bool1, nu1_map, 0)
nu2_map = np.where(mask_bool2, nu2_map, 0)

f1 = nmt.NmtField(mask_nu1, [nu1_map], n_iter=0)
f2 = nmt.NmtField(mask_nu2, [nu2_map], n_iter=0)

# %%
pcl_nmt = nmt.compute_coupled_cell(f1, f2)

# %%
idx = f'{nu1}x{nu2}'

ells = np.arange(LMAX)

plt.plot(ells, 
         cl_cibxcib_fullmission_beam_corrected[f'{idx}'],
         label = r'HP $\tilde{C} (\ell)$',
         alpha = 0.5)

plt.plot(ells, 
         pcl_nmt[0, :LMAX],
         label = r'NMT $\tilde{C} (\ell)$',
         alpha = 0.5)

plt.xlabel(r"$\ell$", fontsize = 20)
plt.ylabel(r"$C (\ell)$", fontsize = 20)
plt.title(f"{idx}")
plt.legend(loc='best')

# %%
# fsky from NMT
fsky_nmt = np.mean(f1.get_mask() * f2.get_mask())

# %%
plt.errorbar(data_lenz19['ell'], data_lenz19[f'{idx}'], 
             yerr = data_lenz19[f'd{idx}'],
             label = 'L19')

plt.plot(ells, 
         pcl_nmt[0,:LMAX]/fsky_nmt,
         label = r'NMT $\tilde{C} (\ell)/f_{\rm sky}$')

plt.xlabel(r"$\ell$", fontsize = 20)
plt.ylabel(r"$C (\ell)$", fontsize = 20)
plt.title(f"{idx}")
plt.legend(loc='best')

# %% [markdown]
# #### Mode-coupling matrix calculation

# %%
nside = 1024

# %%
delta_ell = 64
b = nmt.NmtBin.from_nside_linear(1024, nlb=delta_ell)

# %%
# NaMaster workspace
w = nmt.NmtWorkspace.from_fields(f1, f2, b)

# %%
# Extract the mode-coupling matrix
mcm = w.get_coupling_matrix()

# Extract bandpower window functions
Bbl = w.get_bandpower_windows().squeeze()

# %%
ls = np.arange(3*nside)

# - binning weights for each bandpower
n_bins = b.get_n_bands()
Fls = np.zeros([n_bins, 3*nside])
for i in range(n_bins):
    Fls[i, b.get_ell_list(i)] = b.get_weight_list(i)

# %%
# Plot MCM
plt.figure(figsize=(5, 5))
plt.title('Mode-coupling matrix')
plt.imshow(mcm, cmap='bone')
plt.ylabel("$\\ell$", fontsize=15)
plt.xlabel("$\\ell'$", fontsize=15)
plt.colorbar()

plt.figure(figsize=(7, 5))
for ll in [10, 50, 100, 150, 200]:
    plt.plot(ls, mcm[ll]/fsky_nmt, label=f'$\\ell={ll}$')
plt.xlabel("$\\ell'$", fontsize=15)
plt.ylabel("$M_{\\ell \\ell'}/f_{\\rm sky}$", fontsize=15)
plt.legend(fontsize=12)
plt.xlim([0, 300])

plt.figure(figsize=(7, 5))
plt.title('Bins vs. bandpower windows')
for i, fl in enumerate(Fls):
    plt.plot(ls, fl, 'k-', alpha=(i+1)/n_bins)
    plt.plot(ls, Bbl[i], 'r-', alpha=(i+1)/n_bins)
plt.xlabel(r'$\ell$', fontsize=15);

# %%
print("Sum of MCM over ell': %.5lf" % (np.dot(mcm, np.ones(len(mcm)))[0]))
print("fsky: %.5lf" % fsky_nmt)
# Out:
# Sum of MCM over ell': 0.16052
# fsky: 0.16082

# %%
# Out:
# 0.16287636756896973

# %%
.16052/.16082 * fsky_cross[f'{idx}']
# Out:
# 0.1625725315394293

# %%
cl_dec_nmt = w.decouple_cell(pcl_nmt)

# %%
# - effective ells for each bandpower
leff_nmt = b.get_effective_ells()

# %%
plt.plot(leff_nmt, cl_dec_nmt[0], 'k.')
plt.errorbar(data_lenz19['ell'], data_lenz19[f'{idx}'], 
             yerr = data_lenz19[f'd{idx}'],
             label = 'L19')
# plt.yscale("log")
# plt.xscale("log")
# Out:
# <ErrorbarContainer object of 3 artists>
